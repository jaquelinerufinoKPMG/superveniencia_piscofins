# %%
import pandas as pd
from itertools import product
import numpy as np
from dotenv import load_dotenv
import os
from src.anexo_c.process_dashboard import process
from tqdm.notebook import tqdm

# %%
load_dotenv()
processamentos = process()

input_dir = os.getenv('input_dir')
output_dir = os.getenv('output_dir')
invalid_dir = os.getenv('invalid_dir')

dashboard_csv = os.path.join(input_dir, "Anexo C", "Diligencia_Contratos.csv")
template_path = os.path.join(input_dir, "Anexo C", "template.xlsx")

value_cols = ['ValorDebito', 'ValorCredito', 'Movimentacao']
detalhes_cols = ['Conta_Nome','Cosif_Nome']

configs = [
    (['Total das Receitas', ' Exclusão'], '(01) Total das Receitas'),
    ([' Exclusão'], '(02) Exclusão'),
    ([' Dedução'], '(03) Dedução'),
    (['Sem efeito'],'Sem efeito no Pis Cofins'),
]

# %%
dashboard = pd.read_csv(dashboard_csv, sep=';', encoding='latin1')

# %%
contratos = dashboard['NumContrato'].unique().tolist()

# %%
import os
import re

# 1) Defina aqui o caminho da pasta e o arquivo de saída
pasta = os.path.join(output_dir, "new outputs")
arquivo_saida = 'numeros_extraidos.txt'

# 2) Regex para capturar só dígitos
padrao = re.compile(r'\d+')

# 3) Lista pra acumular as sequências numéricas
numeros = []

for nome_arquivo in os.listdir(pasta):
    achados = padrao.findall(nome_arquivo)  # e.g. ['123','456']
    if achados:
        numeros.append(''.join(achados))     # => '123456'

# 4) Grava no TXT, uma sequência por linha
with open(arquivo_saida, 'w', encoding='utf-8') as f:
    for seq in numeros:
        f.write(seq + '\n')

print(f"✅ Extraídos {len(numeros)} itens e salvos em '{arquivo_saida}'")


nao_encontrados_3 = set()
if os.path.isfile("numeros_extraidos.txt"):
    with open("numeros_extraidos.txt", "r") as f:
        nao_encontrados_3 = set(line.strip() for line in f)

# Filtre os contratos removendo aqueles que estão na lista de não encontrados
contratos = [contrato for contrato in contratos if str(contrato) not in nao_encontrados_3]

for contrato in tqdm(contratos, unit="contrato"):
    tqdm.desc = f"processando contrato: {contrato}"
    dashboard_filtro = dashboard[(dashboard['NumContrato'] == contrato)]


    dashboard_filtro = processamentos.replicar_anos_com_detalhes(dashboard_filtro,
                                                                pis_col='PIS',
                                                                ano_mes_col='AnoMes',
                                                                detalhes_cols=detalhes_cols,
                                                                value_cols=value_cols,
                                                                fill_value=0)
    final = pd.DataFrame()

# para cada filtro, gera o bloco e concatena
    for filtro, desc in configs:
        bloco = processamentos.agrupa_receitas(dashboard_filtro, filtro, desc)
        final = pd.concat([final, bloco], ignore_index=True)



    df_pis_cofins = processamentos.calcula_pis_cofins(final)



    final = pd.concat([final, df_pis_cofins], ignore_index=True)


    final = final[['Ano', 'Descrição', 'Conta_Nome', 'Cosif_Nome', 'ValorCredito', 'Movimentacao']]

    df = final.copy()
    output_path   = os.path.join(output_dir, "new outputs", f"C{contrato}.xlsx")

    processamentos.atualizar_template_pivos(
        template_path=template_path,
        output_path=output_path,
        df=df,
        contrato=contrato
    )
# Out:
# ✅ Extraídos 140 itens e salvos em 'numeros_extraidos.txt'
#   0%|          | 0/21143 [00:00<?, ?contrato/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 67
#      64 df = final.copy()
#      65 output_path   = os.path.join(output_dir, "new outputs", f"C{contrato}.xlsx")
# ---> 67 processamentos.atualizar_template_pivos(
#      68     template_path=template_path,
#      69     output_path=output_path,
#      70     df=df,
#      71     contrato=contrato
#      72 )
#
# File c:\dev\Itau\Superveniência\superveniencia_piscofins\src\anexo_c\process_dashboard.py:212, in atualizar_template_pivos(self, template_path, output_path, df, contrato, data_sheet, pivot_sheet, table_index, contract_cell, start_row_hide)
#     210 # 1) Atualiza a tabela de dados
#     211 ws_data = wb.sheets[data_sheet]
# --> 212 tbl = ws_data.api.ListObjects(table_index)
#     213 hdr_row = tbl.HeaderRowRange.Row
#     214 hdr_col = tbl.HeaderRowRange.Column
#
# File c:\dev\Itau\Superveniência\.venv\Lib\site-packages\xlwings\main.py:2482, in Range.value(self, data)
#    2480 @value.setter
#    2481 def value(self, data):
# -> 2482     conversion.write(data, self, self._options)
#
# File c:\dev\Itau\Superveniência\.venv\Lib\site-packages\xlwings\conversion\__init__.py:110, in write(value, rng, options, engine_name)
#     106 pipeline = (
#     107     accessors.get(convert, convert).router(value, rng, options).writer(options)
#     108 )
#     109 ctx = ConversionContext(rng=rng, value=value, engine_name=engine_name)
# --> 110 pipeline(ctx)
#     111 return ctx.value
#
# File c:\dev\Itau\Superveniência\.venv\Lib\site-packages\xlwings\conversion\framework.py:79, in Pipeline.__call__(self, *args, **kwargs)
#      77 def __call__(self, *args, **kwargs):
#      78     for stage in self:
# ---> 79         stage(*args, **kwargs)
#
# File c:\dev\Itau\Superveniência\.venv\Lib\site-packages\xlwings\conversion\standard.py:76, in WriteValueToRangeStage.__call__(self, ctx)
#      74 scalar = ctx.meta.get("scalar", False)
#      75 if not scalar:
# ---> 76     ctx.range = ctx.range.resize(len(ctx.value), len(ctx.value[0]))
#      78 self._write_value(ctx.range, ctx.value, scalar)
#
# File c:\dev\Itau\Superveniência\.venv\Lib\site-packages\xlwings\main.py:2787, in Range.resize(self, row_size, column_size)
#    2784 else:
#    2785     column_size = self.shape[1]
# -> 2787 return Range(self(1, 1), self(row_size, column_size)).options(**self._options)
#
# File c:\dev\Itau\Superveniência\.venv\Lib\site-packages\xlwings\main.py:1827, in Range.__init__(self, cell1, cell2, **options)
#    1825     if cell1.sheet != cell2.sheet:
#    1826         raise ValueError("Ranges are not on the same sheet")
# -> 1827     impl = cell1.sheet.range(cell1, cell2).impl
#    1828 elif cell2 is None and isinstance(cell1, str):
#    1829     impl = apps.active.range(cell1).impl
#
# File c:\dev\Itau\Superveniência\.venv\Lib\site-packages\xlwings\main.py:1457, in Sheet.range(self, cell1, cell2)
#    1455     cell1 = cell1.impl
#    1456 if isinstance(cell2, Range):
# -> 1457     if cell2.sheet != self:
#    1458         raise ValueError("Second range is not on this sheet")
#    1459     cell2 = cell2.impl
#
# File c:\dev\Itau\Superveniência\.venv\Lib\site-packages\xlwings\main.py:1381, in Sheet.__ne__(self, other)
#    1380 def __ne__(self, other):
# -> 1381     return not self.__eq__(other)
#
# File c:\dev\Itau\Superveniência\.venv\Lib\site-packages\xlwings\main.py:1376, in Sheet.__eq__(self, other)
#    1373 def __eq__(self, other):
#    1374     return (
#    1375         isinstance(other, Sheet)
# -> 1376         and self.book == other.book
#    1377         and self.name == other.name
#    1378     )
#
# File c:\dev\Itau\Superveniência\.venv\Lib\site-packages\xlwings\main.py:1438, in Sheet.book(self)
#    1435 @property
#    1436 def book(self):
#    1437     """Returns the Book of the specified Sheet. Read-only."""
# -> 1438     return Book(impl=self.impl.book)
#
# File c:\dev\Itau\Superveniência\.venv\Lib\site-packages\xlwings\_xlwindows.py:1002, in Sheet.book(self)
#    1000 @property
#    1001 def book(self):
# -> 1002     return Book(xl=self.xl.Parent)
#
# File c:\dev\Itau\Superveniência\.venv\Lib\site-packages\xlwings\_xlwindows.py:199, in COMRetryObjectWrapper.__getattr__(self, item)
#     197 while True:
#     198     try:
# --> 199         v = getattr(self._inner, item)
#     200         if isinstance(v, (CDispatch, CoClassBaseClass, DispatchBaseClass)):
#     201             return COMRetryObjectWrapper(v)
#
# File c:\dev\Itau\Superveniência\.venv\Lib\site-packages\xlwings\_win32patch.py:55, in CoClassBaseClass.__getattr__(self, attr)
#      53 d = self.__dict__["_dispobj_"]
#      54 if d is not None:
# ---> 55     return getattr(d, attr)
#      56 raise AttributeError(attr)
#
# File c:\dev\Itau\Superveniência\.venv\Lib\site-packages\win32com\client\__init__.py:589, in DispatchBaseClass.__getattr__(self, attr)
#     587 if args is None:
#     588     raise AttributeError(f"'{self!r}' object has no attribute '{attr}'")
# --> 589 return self._ApplyTypes_(*args)
#
# File c:\dev\Itau\Superveniência\.venv\Lib\site-packages\win32com\client\__init__.py:579, in DispatchBaseClass._ApplyTypes_(self, dispid, wFlags, retType, argTypes, user, resultCLSID, *args)
#     578 def _ApplyTypes_(self, dispid, wFlags, retType, argTypes, user, resultCLSID, *args):
# --> 579     return self._get_good_object_(
#     580         self._oleobj_.InvokeTypes(dispid, 0, wFlags, retType, argTypes, *args),
#     581         user,
#     582         resultCLSID,
#     583     )
#
# File c:\dev\Itau\Superveniência\.venv\Lib\site-packages\win32com\client\__init__.py:605, in DispatchBaseClass._get_good_object_(self, obj, obUserName, resultCLSID)
#     604 def _get_good_object_(self, obj, obUserName=None, resultCLSID=None):
# --> 605     return _get_good_object_(obj, obUserName, resultCLSID)
#
# File c:\dev\Itau\Superveniência\.venv\Lib\site-packages\win32com\client\__init__.py:623, in _get_good_object_(obj, obUserName, resultCLSID)
#     621     return tuple(map(_get_good_object_, obj, obUserNameTuple, resultCLSIDTuple))
#     622 else:
# --> 623     return _get_good_single_object_(obj, obUserName, resultCLSID)
#
# File c:\dev\Itau\Superveniência\.venv\Lib\site-packages\win32com\client\__init__.py:611, in _get_good_single_object_(obj, obUserName, resultCLSID)
#     609 def _get_good_single_object_(obj, obUserName=None, resultCLSID=None):
#     610     if isinstance(obj, _PyIDispatchType):
# --> 611         return Dispatch(obj, obUserName, resultCLSID)
#     612     return obj
#
# File c:\dev\Itau\Superveniência\.venv\Lib\site-packages\win32com\client\__init__.py:117, in Dispatch(dispatch, userName, resultCLSID, typeinfo, clsctx)
#     115 """Creates a Dispatch based COM object."""
#     116 dispatch, userName = dynamic._GetGoodDispatchAndUserName(dispatch, userName, clsctx)
# --> 117 return __WrapDispatch(dispatch, userName, resultCLSID, typeinfo, clsctx=clsctx)
#
# File c:\dev\Itau\Superveniência\.venv\Lib\site-packages\win32com\client\__init__.py:39, in __WrapDispatch(dispatch, userName, resultCLSID, typeinfo, clsctx, WrapperClass)
#      35     typeinfo = dispatch.GetTypeInfo()
#      36     if (
#      37         typeinfo is not None
#      38     ):  # Some objects return NULL, some raise exceptions...
# ---> 39         resultCLSID = str(typeinfo.GetTypeAttr()[0])
#      40 except (pythoncom.com_error, AttributeError):
#      41     pass
#
# KeyboardInterrupt:
