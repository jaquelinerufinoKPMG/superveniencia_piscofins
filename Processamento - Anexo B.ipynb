# %%
from src.anexo_b.process_b_attachment import processar_anexo_b

# %%
caminho_csv = r"data\input\anexo_b\Nova Base Diligencia 2014_v2.csv"
output_dir = r"data\output\anexo_b"

# %%
processar_anexo_b(caminho_csv, output_dir)
# Out:
# Total de linhas: 14,999,093
# Total de contratos: 22,881
# Salvo: data\output\anexo_b\B0006306.xlsx
# Salvo: data\output\anexo_b\B0014227.xlsx
# Salvo: data\output\anexo_b\B0035923.xlsx
# Salvo: data\output\anexo_b\B0067078.xlsx
# Salvo: data\output\anexo_b\B0074509.xlsx
# Salvo: data\output\anexo_b\B0097740.xlsx
# Salvo: data\output\anexo_b\B0107213.xlsx
# Salvo: data\output\anexo_b\B0146540.xlsx
# Salvo: data\output\anexo_b\B0150644.xlsx
# Salvo: data\output\anexo_b\B0150889.xlsx
# Salvo: data\output\anexo_b\B0154561.xlsx
# Salvo: data\output\anexo_b\B0165294.xlsx
# Salvo: data\output\anexo_b\B0174820.xlsx
# Salvo: data\output\anexo_b\B0174951.xlsx
# Salvo: data\output\anexo_b\B0175856.xlsx
# Salvo: data\output\anexo_b\B0176774.xlsx
# Salvo: data\output\anexo_b\B0183600.xlsx
# Salvo: data\output\anexo_b\B0185670.xlsx
# Salvo: data\output\anexo_b\B0185792.xlsx
# Salvo: data\output\anexo_b\B0186490.xlsx
# Salvo: data\output\anexo_b\B0187993.xlsx
# Salvo: data\output\anexo_b\B0195005.xlsx
# Salvo: data\output\anexo_b\B0199647.xlsx
# Salvo: data\output\anexo_b\B0200791.xlsx
# Salvo: data\output\anexo_b\B0202434.xlsx
# Salvo: data\output\anexo_b\B0203172.xlsx
# Salvo: data\output\anexo_b\B0210515.xlsx
# Salvo: data\output\anexo_b\B0211870.xlsx
# Salvo: data\output\anexo_b\B0213400.xlsx
# Salvo: data\output\anexo_b\B0221458.xlsx
# Salvo: data\output\anexo_b\B0221655.xlsx
# Salvo: data\output\anexo_b\B0225312.xlsx
# Salvo: data\output\anexo_b\B0230912.xlsx
# Salvo: data\output\anexo_b\B0231738.xlsx
# Salvo: data\output\anexo_b\B0232377.xlsx
# Salvo: data\output\anexo_b\B0241620.xlsx
# Salvo: data\output\anexo_b\B0259378.xlsx
# Salvo: data\output\anexo_b\B0263632.xlsx
# Salvo: data\output\anexo_b\B0265655.xlsx
# Salvo: data\output\anexo_b\B0267202.xlsx
# Salvo: data\output\anexo_b\B0280466.xlsx
# Salvo: data\output\anexo_b\B0292633.xlsx
# Salvo: data\output\anexo_b\B0295005.xlsx
# Salvo: data\output\anexo_b\B0300870.xlsx
# Salvo: data\output\anexo_b\B0301504.xlsx
# Salvo: data\output\anexo_b\B0304610.xlsx
# Salvo: data\output\anexo_b\B0316952.xlsx
# Salvo: data\output\anexo_b\B0330033.xlsx
# Salvo: data\output\anexo_b\B0333944.xlsx
# Salvo: data\output\anexo_b\B0343237.xlsx
# Salvo: data\output\anexo_b\B0345452.xlsx
# Salvo: data\output\anexo_b\B0352546.xlsx
# Salvo: data\output\anexo_b\B0358397.xlsx
# Salvo: data\output\anexo_b\B0377859.xlsx
# Salvo: data\output\anexo_b\B0403642.xlsx
# Salvo: data\output\anexo_b\B0405490.xlsx
# Salvo: data\output\anexo_b\B0406628.xlsx
# Salvo: data\output\anexo_b\B0407396.xlsx
# Salvo: data\output\anexo_b\B0410807.xlsx
# Salvo: data\output\anexo_b\B0411310.xlsx
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 processar_anexo_b(caminho_csv, output_dir)
#
# File c:\_projects\dev\superveniencia_csll\src\anexo_b\process_b_attachment.py:56, in processar_anexo_b(caminho_csv, pasta_saida, coluna_contrato, sep, encoding)
#      47 col = (
#      48     df["DATA GERACAO"]
#      49     .astype(str)
#      50     .str.strip()
#      51     .replace({"99999999": None, "00000000": None, "": None})
#      52 )
#      54 df["DATA GERACAO"] = pd.to_datetime(col, format="%Y%m%d", errors="coerce")
# ---> 56 exportar_contratos_para_excel(df, coluna_contrato, pasta_saida)
#
# File c:\_projects\dev\superveniencia_csll\src\anexo_b\process_b_attachment.py:87, in exportar_contratos_para_excel(df, coluna_contrato, pasta_saida)
#      84 nome_arquivo = f"B{contrato}.xlsx"
#      85 caminho_saida = pasta_saida / nome_arquivo
# ---> 87 grupo.to_excel(caminho_saida, index=False, sheet_name="Conta Gráfica")
#      88 print(f"Salvo: {caminho_saida}")
#
# File c:\_projects\dev\superveniencia_csll\.venv\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\_projects\dev\superveniencia_csll\.venv\Lib\site-packages\pandas\core\generic.py:2436, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2423 from pandas.io.formats.excel import ExcelFormatter
#    2425 formatter = ExcelFormatter(
#    2426     df,
#    2427     na_rep=na_rep,
#    (...)   2434     inf_rep=inf_rep,
#    2435 )
# -> 2436 formatter.write(
#    2437     excel_writer,
#    2438     sheet_name=sheet_name,
#    2439     startrow=startrow,
#    2440     startcol=startcol,
#    2441     freeze_panes=freeze_panes,
#    2442     engine=engine,
#    2443     storage_options=storage_options,
#    2444     engine_kwargs=engine_kwargs,
#    2445 )
#
# File c:\_projects\dev\superveniencia_csll\.venv\Lib\site-packages\pandas\io\formats\excel.py:962, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#     959 finally:
#     960     # make sure to close opened file handles
#     961     if need_save:
# --> 962         writer.close()
#
# File c:\_projects\dev\superveniencia_csll\.venv\Lib\site-packages\pandas\io\excel\_base.py:1357, in ExcelWriter.close(self)
#    1355 def close(self) -> None:
#    1356     """synonym for save, to make it more file-like"""
# -> 1357     self._save()
#    1358     self._handles.close()
#
# File c:\_projects\dev\superveniencia_csll\.venv\Lib\site-packages\pandas\io\excel\_openpyxl.py:110, in OpenpyxlWriter._save(self)
#     106 def _save(self) -> None:
#     107     """
#     108     Save workbook to disk.
#     109     """
# --> 110     self.book.save(self._handles.handle)
#     111     if "r+" in self._mode and not isinstance(self._handles.handle, mmap.mmap):
#     112         # truncate file to the written content
#     113         self._handles.handle.truncate()
#
# File c:\_projects\dev\superveniencia_csll\.venv\Lib\site-packages\openpyxl\workbook\workbook.py:386, in Workbook.save(self, filename)
#     384 if self.write_only and not self.worksheets:
#     385     self.create_sheet()
# --> 386 save_workbook(self, filename)
#
# File c:\_projects\dev\superveniencia_csll\.venv\Lib\site-packages\openpyxl\writer\excel.py:294, in save_workbook(workbook, filename)
#     292 workbook.properties.modified = datetime.datetime.now(tz=datetime.timezone.utc).replace(tzinfo=None)
#     293 writer = ExcelWriter(workbook, archive)
# --> 294 writer.save()
#     295 return True
#
# File c:\_projects\dev\superveniencia_csll\.venv\Lib\site-packages\openpyxl\writer\excel.py:275, in ExcelWriter.save(self)
#     273 def save(self):
#     274     """Write data into the archive."""
# --> 275     self.write_data()
#     276     self._archive.close()
#
# File c:\_projects\dev\superveniencia_csll\.venv\Lib\site-packages\openpyxl\writer\excel.py:77, in ExcelWriter.write_data(self)
#      74     custom_override = CustomOverride()
#      75     self.manifest.append(custom_override)
# ---> 77 self._write_worksheets()
#      78 self._write_chartsheets()
#      79 self._write_images()
#
# File c:\_projects\dev\superveniencia_csll\.venv\Lib\site-packages\openpyxl\writer\excel.py:215, in ExcelWriter._write_worksheets(self)
#     212 for idx, ws in enumerate(self.workbook.worksheets, 1):
#     214     ws._id = idx
# --> 215     self.write_worksheet(ws)
#     217     if ws._drawing:
#     218         self._write_drawing(ws._drawing)
#
# File c:\_projects\dev\superveniencia_csll\.venv\Lib\site-packages\openpyxl\writer\excel.py:200, in ExcelWriter.write_worksheet(self, ws)
#     198 else:
#     199     writer = WorksheetWriter(ws)
# --> 200     writer.write()
#     202 ws._rels = writer._rels
#     203 self._archive.write(writer.out, ws.path[1:])
#
# File c:\_projects\dev\superveniencia_csll\.venv\Lib\site-packages\openpyxl\worksheet\_writer.py:359, in WorksheetWriter.write(self)
#     355 """
#     356 High level
#     357 """
#     358 self.write_top()
# --> 359 self.write_rows()
#     360 self.write_tail()
#     361 self.close()
#
# File c:\_projects\dev\superveniencia_csll\.venv\Lib\site-packages\openpyxl\worksheet\_writer.py:125, in WorksheetWriter.write_rows(self)
#     123 with xf.element("sheetData"):
#     124     for row_idx, row in self.rows():
# --> 125         self.write_row(xf, row, row_idx)
#     127 self.xf.send(None)
#
# File c:\_projects\dev\superveniencia_csll\.venv\Lib\site-packages\openpyxl\worksheet\_writer.py:147, in WorksheetWriter.write_row(self, xf, row, row_idx)
#     141 if (
#     142     cell._value is None
#     143     and not cell.has_style
#     144     and not cell._comment
#     145     ):
#     146     continue
# --> 147 write_cell(xf, self.ws, cell, cell.has_style)
#
# File c:\_projects\dev\superveniencia_csll\.venv\Lib\site-packages\openpyxl\cell\_writer.py:128, in lxml_write_cell(xf, worksheet, cell, styled)
#     125                 xf.write(el)
#     127 else:
# --> 128     with xf.element("v"):
#     129         if value is not None:
#     130             xf.write(safe_string(value))
#
# KeyboardInterrupt:
